# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuhdiaja/244107020017_Machine_Learning/blob/main/JS01/TG1_244107020017_Muhammad_Zuhdi_Y.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyprep

# %%
# !pip install scipy

# %%
# !pip install wandb

# %%
# !pip install pyECG
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# ## Jelaskan kegunakan masing-masing library tersebut.
#
# 1. pyPREP : library Python yang digunakan untuk melakukan preprocessing data EEG (electroencephalography). Library ini membantu membersihkan dan menyiapkan sinyal EEG sebelum digunakan untuk analisis atau pemrosesan lebih lanjut.
# 2. Scipy  : library Python untuk komputasi ilmiah. SciPy menyediakan berbagai fungsi untuk statistik, optimasi, aljabar linear, integrasi, interpolasi, dan pemrosesan sinyal.
# 3. wandb :tools yang digunakan untuk melakukan experiment tracking dan membantu proses pengelolaan eksperimen machine learning.
# 4. pyECG : toollkit Python yang digunakan untuk membaca dan menulis data ECG (electrocardiogram) dalam beberapa format dataset ECG.

# %% [markdown]
# ## Bagian 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan. = buat deepfake seseorang tanpa izin dan menyebarkannya untuk merugikan orang tersebut. Tindakan ini dapat melanggar privasi, merugikan korban, dan berpotensi melanggar hukum terkait data pribadi atau penyalahgunaan identitas.
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan. = Penggunaan AI membutuhkan GPU, server, dan data center yang mengonsumsi listrik cukup besar. Hal tersebut dapat meningkatkan emisi karbon dan kebutuhan energi untuk pendinginan.
